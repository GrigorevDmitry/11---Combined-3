# %% [markdown]
# <div class="alert alert-info"><big><b>Комментарий ревьюера</b></big><br>Привет! 👋<br><br> Ничего не поменялось, меня всё ещё зовут Дмитрий Кирсанов. <br><br>Комментарии всё ещё обозначены пометкой <b>Комментарий ревьюера</b> и всё ещё содержат описание <br><span class="alert-success">✔️ хорошего, 👍 отличного, 📝 советов</span>,&nbsp;&nbsp;<span class="alert-warning">📌 важного, ⚠️ замечаний, 💡 рекомендаций</span>,&nbsp;&nbsp;<span class="alert-danger">🔧 доработок, 🚫 ошибок или 👀 вопросов.</span><br><br>После того, как замечание будет устранено, я сменю красный цвет на жёлтый, чтобы тебе было удобнее выделять те места, которые требуют доработки. Код, которым я предлагаю выделять твои комментарии<!--
# НЕ НАДО КОПИРОВАТЬ КОД, ПРИ ПОМОЩИ КОТОРОГО Я ВЫВОЖУ КОД-->:<br><code>&lt;div class=&quot;alert btn-primary&quot;&gt;&lt;b&gt;Комментарий студента:&lt;/b&gt;&lt;br&gt;   Ок   &lt;/div&gt;</code><br><!--
# КОПИРОВАТЬ НАДО, КОГДА ВИДЕН ОФОРМЛЕННЫЙ ТЕКСТ-->Всё ещё просьба задавать вопросы и описывать изменения в проект.</div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔁Комментарий студента:</b>
# Привет! Выполнял проект на локальном компе, перед сдачей переношу на тренажер. Замечаю, что что-то поплыло и выглядит не совсем как на локальном. Глаз замылился, могу что-то пропустить. Проверь, пожалуйста, есть ли грубые ошибки.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔁Комментарий студента V2:</b>
# К сожалению, болел 5 дней, не было доступа к компьютеру. Проект чуть сырой, обязуюсь доделать до красоты, лишь бы уложиться в дедлайн
# </div>

# %% [markdown]
# <div class="alert alert-success"><b>Комментарий ревьюера</b>&nbsp;✔️<br>
# Всё в целом верно, но не хватает обоснований графических для презентации.
# </div><div class="alert alert-success"><b>Комментарий ревьюера</b>&nbsp;✔️<br>
# Титульный лист презентации должен быть оформлен так, чтобы на неё было удобно сослаться. В самой презентации не нужно мельчить и нужно снабжать графики тезисами. У вас должны быть упомянуты все характеристики и в визуально наглядном виде представлены не только результаты работы (сформированные сегменты и рекомендации), но и ход ваших мыслей, почему именно эти характеристики вы взяли и именно так, а другие не взяли. Обязательно указываем типичного отточного, подчёркиваем чем он отличается от типичного неотточного, что сравнивали стат.гипотезами; результаты корреляционного анализа читаемо; уровни оттока по категориальным характеристикам; как поняли что непрерывные нужно разделить именно так, как разделили.
# </div>

# %% [markdown]
# # Анализ оттока и привлечение клиентов банка «Метанпром».

# %% [markdown]
# Цель: Проанализировать клиентов регионального банка и выделить сегменты клиентов, которые `склонны оставаться в банке`.
#
# Задачи:
#
# 1. Изучение датафрейма, подготовка данных
#
#
# 2. Предобработка данных
#
# 2.1. Исследовать пропущенные значения;
#
# 2.2. Исследовать соответствие типов;
#
# 2.3. Исследовать дубликаты;
#
# 2.4.Проверить корректность наименований колонок;
#
# 2.5.Переименовать колонки;
#
# 2.6.Создать новые колонки, характеризующие пол и город клиентов;
#
# 2.7.Удалить дубликаты;
#
# 2.8.Привести типы;
#
# 2.9.Заменить пропущенные значения.
#
#
#
# 3. Исследовательский анализ данных
#
# 3.1.Изучение влияния характеристик на отток.
#
# 3.2.Проверить влияние города на вероятность ухода.
#
# 3.3.Проверить влияние личных данных(возраст, пол) на вероятность ухода.
#
# 3.4.Проверить влияние финансовых данных(баллы кредитного скоринга, баланс, собственность, количество продуктов) на вероятность ухода.
#
#
# 4. Сегментация наиболее лояльных пользователей на основании иследовательского анализа.
#
#
# 5. Формулировка и проверка статистических гипотез.
#
# 5.1.Проверка гипотезу различия дохода между теми клиентами, которые ушли и теми, которые остались.
#
# 5.2.Проверка гипотезу различия города между теми клиентами, которые ушли и теми, которые остались.
#
# 5.3.Проверка гипотезу различия возраста между теми клиентами, которые ушли и теми, которые остались.
#
# 5.4.Проверка гипотезу различия пола между теми клиентами, которые ушли и теми, которые остались.
#
# 5.5.Проверка гипотезу различия количества продуктов между теми клиентами, которые ушли и теми, которые остались.
#
# 5.6.Проверка гипотезу о наличии кредитной карты у тех клиентов, которые ушли и тех, которые остались.
#
#
# 6. Выводы, рекомендации, приоритетные сегменты.
#
#
# 7. Презентация.

# %% [markdown]
# Презентация: https://disk.yandex.ru/i/EzqFpQr3Ys54tA

# %% [markdown]
# <div class="alert alert-success"><b>Комментарий ревьюера</b>&nbsp;✔️<br>
# Формат pdf, есть дата, автор, в начале указаны цели, соблюдён баланс графической и текстовой информации, слайды по ключевым моментам работы:
#
# * есть корреляционный анализ
# * есть выводы и рекомендации
# </div>
# <div class="alert alert-warning"><b>Комментарий ревьюера</b>&nbsp;⚠️<br>
# На матрице корреляций люди ничего не увидят. Диаграммы абсолютного распределения категориальных (countplot) будут менее понятны менеджменту, особенно для не бинарных характеристик.
# </div>
# <div class="alert alert-warning"><b>Комментарий ревьюера</b>&nbsp;🔧<br>
# По категориальным переменным графики с абсолютными значениями не дают нужной точности при сравнении категорий характеристик разного масштаба.
#
# Нет диаграмм по уровню оттока по категориальным.
#
# Возраст категоризирован, не объяснено почему именно так (вообще нет ни одной гистограммы по непрерывным, хотя баланс и скор используется в сегментации).
#
# Нет сравнения портретов. Нет описания сегментов - по каким признакам отобраны указано, а какие у них свойства не указано. Нет рекомендаций для сегментов.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔁Комментарий студента:</b>
#
# Исправлено
#
# </div>

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера 2</b>&nbsp;🔴<br>
# Не увидел новых графиков крутых с уровнями оттока. Также нужно будет нормированные переделать и вставить. Это последний момент, который надо доделать.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔁Комментарий студента:</b>
#
# Исправлено, добавлен пункт 3.5 - сделана группировка по категории с последующей аггрегацией информации об оттоке, и из них столбиковые диаграммы со средним уровнем оттока по банку.
#
# </div>

# %% [markdown]
# <div class="alert alert-success"><b>Комментарий ревьюера 3&nbsp;<big>✔️</big></b></div>

# %% [markdown]
# ## Анализ данных

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера 2</b>&nbsp;🔧<br>
# Я заметил что первая ячейка имеет номер выполнения, отличный от <tt>[1]</tt>. Это может приводить к тому, что не вызовут ошибку какие-то изменения кода, которые вызвали бы ошибку после перезапуска ноутбука (или при его запуске на другой машине), например потому, что в памяти сохраняются переменные, которые были сформированы до того, как код был изменён. Поэтому важно выполнять ячейки с первой по последнюю строго последовательным образом перед тем, как отправлять их кому-то.
# </div>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from scipy import stats as st
import matplotlib.pyplot as plt

# %% [markdown]
# <div class="alert alert-success"><b>Комментарий ревьюера</b>&nbsp;📝<br>
# Хорошо, что в начале работы помещаешь описание проекта, это позволит читателям быстро понять, о чём работа. Также верно, что выполнение ячеек было последовательное с самой первой и у неё номер <tt>[1]</tt>.
#
# Импорт библиотек в самом начале позволит быстро понять, какое окружение нужно для ноутбука. Такой код проще поддерживать.
#
# Если ты не используешь потом какие-то библиотеки или методы, их импорт можно закомментировать. Если передумаешь, то сможешь убрать пометки комментирования и всё снова заработает.
#
# <a href='https://pythonworld.ru/osnovy/pep-8-rukovodstvo-po-napisaniyu-koda-na-python.html'>Материал по импорту.</a> Также есть простые правила — не стоит импортировать дважды одно и то же, желательно разбивать импорт на группы (отделять друг от друга переносами строк и комментариями), при этом импорт <a href='https://docs.python.org/3/library/index.html'>стандартных библиотек</a> стоит размещать в начале.
# </div>

# %%
#path = 'bank_dataset.csv' #для локального
path = 'https://www.dropbox.com/s/ag2n3blwin8p8ot/bank_dataset.csv?dl=1' #для общего

df = pd.read_csv(path)

# %%
df.head(5)
# Out:
#     user_id  score       city gender  age  objects    balance  products  \
# 0  15677338    619  Ярославль      Ж   42        2        NaN         1
# 1  15690047    608    Рыбинск      Ж   41        1   83807.86         1
# 2  15662040    502  Ярославль      Ж   42        8  159660.80         3
# 3  15744090    699  Ярославль      Ж   39        1        NaN         2
# 4  15780624    850    Рыбинск      Ж   43        2  125510.82         1
#
#    credit_card  loyalty  estimated_salary  churn  female  male  city_ros  \
# 0            1        1         101348.88      1       1     0         0
# 1            0        1         112542.58      0       1     0         0
# 2            1        0         113931.57      1       1     0         0
# 3            0        0          93826.63      0       1     0         0
# 4            1        1          79084.10      0       1     0         0
#
#    city_ryb  city_yar
# 0         0         1
# 1         1         0
# 2         0         1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   userid            10000 non-null  int64
#  1   score             10000 non-null  int64
#  2   City              10000 non-null  object
#  3   Gender            10000 non-null  object
#  4   Age               10000 non-null  int64
#  5   Objects           10000 non-null  int64
#  6   Balance           6383 non-null   float64
#  7   Products          10000 non-null  int64
#  8   CreditCard        10000 non-null  int64
#  9   Loyalty           10000 non-null  int64
#  10  estimated_salary  10000 non-null  float64
#  11  Churn             10000 non-null  int64
# dtypes: float64(2), int64(8), object(2)
# memory usage: 937.6+ KB

# %%
df.describe()
# Out:
#              userid         score           Age       Objects        Balance  \
# count  1.000000e+04  10000.000000  10000.000000  10000.000000    6383.000000
# mean   1.573368e+07    650.528800     38.921800      5.012800  119827.493793
# std    7.193619e+04     96.653299     10.487806      2.892174   30095.056462
# min    1.560844e+07    350.000000     18.000000      0.000000    3768.690000
# 25%    1.567126e+07    584.000000     32.000000      3.000000  100181.975000
# 50%    1.573347e+07    652.000000     37.000000      5.000000  119839.690000
# 75%    1.579597e+07    718.000000     44.000000      7.000000  139512.290000
# max    1.585843e+07    850.000000     92.000000     10.000000  250898.090000
#
#            Products   CreditCard       Loyalty  estimated_salary         Churn
# count  10000.000000  10000.00000  10000.000000      10000.000000  10000.000000
# mean       1.530200      0.70550      0.515100     100090.239881      0.203700
# ...

# %% [markdown]
# ### Вывод.
# Датафрейм хранит информацию о 10000 событиях, разделенных на 12 столбцов. Данная информация соответствует описанию проекта.
#
# Данные загружены, открываются, поддаются анализу.

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Обработка столбцов

# %%
df.columns = df.columns.str.lower()

# %%
df = df.rename(columns={'userid' : 'user_id', 'creditcard' : 'credit_card'})

# %% [markdown]
# <div class="alert alert-success"><b>Комментарий ревьюера</b>&nbsp;👍<br>
# Хорошее использование <a href='https://pandas.pydata.org/pandas-docs/stable/user_guide/text.html'>строкового ацессора</a> pandas
#
# Стоит также не забывать, что у него есть другие полезные методы, кроме .lower
#
# Правильно пользуешься .rename
# </div>

# %%
df.columns
# Out:
# Index(['user_id', 'score', 'city', 'gender', 'age', 'objects', 'balance',
#        'products', 'credit_card', 'loyalty', 'estimated_salary', 'churn'],
#       dtype='object')

# %%
print('Обнаружено дубликатов:', df.duplicated().sum())
# Out:
# Обнаружено дубликатов: 0

# %%
#df['gender_bool'] = df['gender'].replace('Ж','False').replace('М','True').astype('bool')

# %%
df['gender_copy'] = df['gender']
df = pd.get_dummies(df, columns=['gender_copy'], drop_first= False )

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔁Комментарий студента:</b>
# Мне понравился твой совет про решение функцией get_dummies().
# </div>

# %%
df['city_copy'] = df['city'] # копия столбца city для get_dummies()
df = pd.get_dummies (df, prefix = 'city', columns=['city_copy'], drop_first= False)

# %%
df = df.rename(columns={'gender_copy_Ж' : 'female', 'gender_copy_М' : 'male'})

# %%
df = df.rename(columns={'city_Ростов Великий' : 'city_ros', 'city_Рыбинск' : 'city_ryb', 'city_Ярославль' : 'city_yar'})

# %% [markdown]
# <div class="alert alert-success"><b>Комментарий ревьюера&nbsp;<big>👍</big></b></div>

# %% [markdown]
# Пропуски

# %%
df.isna().sum()
# Out:
# user_id                0
# score                  0
# city                   0
# gender                 0
# age                    0
# objects                0
# balance             3617
# products               0
# credit_card            0
# loyalty                0
# estimated_salary       0
# churn                  0
# female                 0
# male                   0
# city_ros               0
# city_ryb               0
# city_yar               0
# dtype: int64

# %%
df.loc[df['balance'].isna()]
# Out:
#        user_id  score       city gender  age  objects  balance  products  \
# 0     15677338    619  Ярославль      Ж   42        2      NaN         1
# 3     15744090    699  Ярославль      Ж   39        1      NaN         2
# 6     15635267    822  Ярославль      М   50        7      NaN         2
# 11    15779909    497    Рыбинск      М   24        3      NaN         2
# 12    15675000    476  Ярославль      Ж   34       10      NaN         2
# ...        ...    ...        ...    ...  ...      ...      ...       ...
# 9989  15648358    841    Рыбинск      М   28        4      NaN         2
# 9992  15699841    726    Рыбинск      М   36        2      NaN         1
# 9994  15762030    800  Ярославль      Ж   29        2      NaN         2
# 9995  15648965    771  Ярославль      М   39        5      NaN         2
# 9997  15627268    709  Ярославль      Ж   36        7      NaN         1
#
#       credit_card  loyalty  estimated_salary  churn  female  male  city_ros  \
# ...

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера</b>&nbsp;🔧<br>
# Не нужно использовать print для вывода датафреймов.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔁Комментарий студента:</b>
# Исправлено
# </div>

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера</b>&nbsp;⚠️<br>При построении <tt>matplotlib</tt> графиков и основанных на данной библиотеке в конце последней строки ячейки можно ставить «<tt>;</tt>» или вызывать метод <tt>plt.show()</tt> для того, чтобы не выводились строки вида <tt>AxesSubplot:</tt> — возвращаемое значение последнего применённого метода.
#
# Если ты не работаешь с этими значениями, не нужно их распечатывать.</div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔁Комментарий студента:</b>
# Исправил, убрал лишнее.
# </div>

# %% [markdown]
# <div class="alert alert-success"><b>Комментарий ревьюера 2&nbsp;<big>✔️</big></b></div>

# %% [markdown]
# ### Изучаю пропуски

# %%
passes = df.loc[(df['balance'].isna())]
passes.sample(5)
# Out:
#        user_id  score       city gender  age  objects  balance  products  \
# 4645  15824880    522  Ярославль      Ж   34        3      NaN         2
# 4121  15648869    628    Рыбинск      М   42        7      NaN         2
# 7740  15768642    665    Рыбинск      Ж   51        8      NaN         1
# 5637  15836079    549  Ярославль      Ж   29        8      NaN         2
# 864   15848185    594  Ярославль      М   38        4      NaN         2
#
#       credit_card  loyalty  estimated_salary  churn  female  male  city_ros  \
# 4645            1        1           3894.34      0       1     0         0
# 4121            0        1         172967.87      0       0     1         0
# 7740            1        1          38928.48      1       1     0         0
# 5637            1        1         189558.44      0       1     0         0
# 864             0        0         186884.04      0       0     1         0
#
#       city_ryb  city_yar
# 4645         0         1
# ...

# %%
passes.describe()
# Out:
#             user_id        score          age      objects  balance  \
# count  3.617000e+03  3617.000000  3617.000000  3617.000000      0.0
# mean   1.573469e+07   649.452861    38.434891     5.071330      NaN
# std    7.194749e+04    96.158798    10.492002     2.860781      NaN
# min    1.560844e+07   350.000000    18.000000     0.000000      NaN
# 25%    1.567226e+07   583.000000    31.000000     3.000000      NaN
# 50%    1.573608e+07   651.000000    37.000000     5.000000      NaN
# 75%    1.579629e+07   717.000000    43.000000     7.000000      NaN
# max    1.585810e+07   850.000000    88.000000    10.000000      NaN
#
#           products  credit_card      loyalty  estimated_salary        churn  \
# count  3617.000000  3617.000000  3617.000000       3617.000000  3617.000000
# mean      1.784628     0.716616     0.517832      98983.559549     0.138236
# std       0.496455     0.450704     0.499751      57730.828955     0.345195
# ...

# %%
for column in passes.columns.drop({'user_id', 'balance'}):
    sns.displot(passes, x=column, hue = 'churn', multiple="stack")
    plt.title(f'Распределение пропусков по параметру {column}')
    plt.ylabel('Кол-во пропусков')
    plt.show()

# %% [markdown]
# 3617 пропусков в столбце "balance", отвечающий за баланс на счёте.
# Учитывая, что describe показал минимальное значение в этом столбце не "0", а "3768.69", принимаю следующее: строки NA в "balance" могут указывать 0 рублей на счету, либо техническую неисправность при выгрузке.
#
# В этом списке 500 человек из оттока.
#
# `Явной взаимосвязи параметров и пропусков не выявлено.`

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера</b>&nbsp;🚫<br>В целом такой подход не оправдан. Рассматривая только строки с пропусками мы, например, видим, что пропусков много в одном из городов. Но никак интерпретировать это не можем, так как это, возможно, просто самый большой город, в котором у нас больше всего клиентов.
#
# Также распределение значений в тех строках, в которых встречаются пропуски, сами по себе, за исключением каких-то крайних случаев (как тут), не покажут нам, аномальное это распределение, отличается оно от распределения строк без пропусков или нет.
# </div>
#
# <div class="alert alert-warning"><b>Комментарий ревьюера</b>&nbsp;🚫<br>Если за минусом шума в рамках каждой из характеристик распределение строк с пропусками повторяет распределение строк без пропусков, то можно сказать, что пропуски имеют тип MCAR (Missing Completely At Random).
#
# Если пропусков почти нет среди какой-то группы, но в остальном они распределены случайно, то это уже MAR (Missing At Random), это значит, что пропуски случайно распределены и связаны с какой-то наблюдаемой характеристикой.
#
# Пропуски типа MNAR (Missing Not At Random) наблюдаются тогда, когда пропуски связаны с какой-то не наблюдаемой характеристикой, которой нету в наших данных.
#
# Чтобы улучшить проект, выяви наличие или отсутствие зависимости пропусков от данных, исследовав данные в разрезе наличия или отсутствия пропусков (одним из методов —  средние, корреляции  с новой фиктивной переменной, связанной с пропусками, графики в разрезе наличия пропусков или доля пропусков по категориям, также можно сделать пару вызовов value_counts(normalize=True) и сравнить проценты распределения).
# </div>

# %%
df['products'].describe() #проверяю столбец продуктов 3 разными способами
# Out:
# count    10000.000000
# mean         1.530200
# std          0.581654
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          2.000000
# max          4.000000
# Name: products, dtype: float64

# %%
np.percentile(df['products'], [95, 99])
# Out:
# array([2., 3.])

# %%
plt.boxplot(df['products']);

# %%
df = df.query('products < 4')

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера</b>&nbsp;🚫<br>Осталась аномалия в продуктах
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔁Комментарий студента:</b>
# Если рассматривать аномалией 4 продукта, то они подчищены.
#
# Исправлено
# </div>

# %% [markdown]
# <div class="alert alert-success"><b>Комментарий ревьюера 2&nbsp;<big>✔️</big></b></div>

# %% [markdown]
# ### Вывод.
# Предобработка звершена.
#
# Данные готовы для анализа.

# %% [markdown]
# ## Исследовательский анализ

# %% [markdown]
# ### Количество ушедших пользователей

# %% [markdown]
# Проверяю соотношение ушедших пользователей, и тех кто остался.

# %%
name = df['churn'].value_counts(sort = True)
colors = ["g", "r"]
labels = ["", "Отток"]
plt.pie(name, colors= colors, labels = labels, autopct='%1.1f%%', shadow=True)
plt.title('Распределение пользователей')
plt.show()

# %%
df['city'].value_counts(True)
# Out:
# Ярославль         0.501509
# Ростов Великий    0.250000
# Рыбинск           0.248491
# Name: city, dtype: float64

# %% [markdown]
# 5014 клиентов - в Ярославле (при населении 570 тыс.)
#
# 2509 - из Ростова (при населении 28 тыс. Это значит, что почти 9% жителей являются клиентами данного банка)
#
# 2477 - из Рыбинска (при населении 177 тыс.)

# %% [markdown]
# ### Рассмотрение взаимосвязей оттока и различных параметров

# %% [markdown]
# <div class="alert alert-danger"><b>Комментарий ревьюера</b>&nbsp;📌<br>
# Перед выделением сегментов, мы сначала на основе анализа средних и медиан по подготовленным данным можем <u>построить портрет отточного и не отточного клиента</u> (часть признаков надо будет правильно закодировать). Чем больше относительная разница в портретах клиентов (постренных на основе средних или медиан - обычно лучше применять среднее, но его могут исказить выбросы), тем больше зависимость между тем, в разрезе чего построены портреты. По бинарным столбцам можно определить, с какой вероятностью уходящий клиент будет мужчиной или женщиной, или из какого-то города и т.п. Это важно, так как по портрету клиента маркетинг сможет составить кампанию для удержания клиентов.
#
# Пожалуйста, по каждой характеристике посчитай на сколько процентов характеристика отточного клиента выше(ниже) характеристики неотточного. </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔁Комментарий студента:</b>
# Исправлено
# </div>

# %%
df.groupby('churn').mean()
# Out:
#             user_id       score        age   objects        balance  products  \
# churn
# 0      1.573390e+07  651.853196  37.408389  5.033279  119535.864270  1.544267
# 1      1.573320e+07  645.101669  44.812342  4.921598  120700.272656  1.398584
#
#        credit_card   loyalty  estimated_salary    female      male  city_ros  \
# churn
# 0         0.707146  0.554565      99738.391772  0.427477  0.572523  0.212859
# 1         0.699545  0.357107     101365.585094  0.556904  0.443096  0.399595
#
#        city_ryb  city_yar
# churn
# 0      0.259199  0.527942
# 1      0.205362  0.395043

# %% [markdown]
# Вывод:
# баллы score в двух группах почти одинаковы;
#
# средний возраст различается: 37 лет у оставшегося клиента и 44 у ушедшего;
#
# среднее количество по имеющимся объектам собственности похоже;
#
# сумма на счетах похожа;
#
# актинвость(loyalty) выше у оставшихся;
#
# в Ростове Великом наблюдается отток, в Рыбинске отток незначительно меньше оставшихся,
#
# в Ярославле отток меньше чем оставшиеся клиенты;
#
# в группе оставшихся клиентов мужчин больше чем женщин.

# %% [markdown]
# <div class="alert alert-danger"><b>Комментарий ревьюера 2</b>&nbsp;🔴<br>
# Пожалуйста транспонируй таблицу выше и в отдельном столбце выведи на сколько процентов показатель отточных больше показателя неотточных, отсортируй по нему. Так мы точно не пропустим никакую значимую характеристику.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔁Комментарий студента:</b>
# Исправлено
# </div>

# %%
df_copy = df.groupby('churn').mean().T
df_copy['res'] = (df_copy[1]/df_copy[0]) - 1
df_copy['res'] = df_copy['res'].map('{:.1%}'.format)
df_copy.rename(columns={'res': 'Соотношение'}, inplace=True)
df_copy.sort_values(by ='Соотношение' , ascending=True, kind='quicksort')

#  сортировка не работает с транспонированными таблицами?
# Out:
# churn                        0             1 Соотношение
# user_id           1.573390e+07  1.573320e+07       -0.0%
# score             6.518532e+02  6.451017e+02       -1.0%
# credit_card       7.071455e-01  6.995448e-01       -1.1%
# objects           5.033279e+00  4.921598e+00       -2.2%
# city_ryb          2.591988e-01  2.053617e-01      -20.8%
# male              5.725229e-01  4.430956e-01      -22.6%
# city_yar          5.279417e-01  3.950430e-01      -25.2%
# loyalty           5.545649e-01  3.571067e-01      -35.6%
# products          1.544267e+00  1.398584e+00       -9.4%
# balance           1.195359e+05  1.207003e+05        1.0%
# estimated_salary  9.973839e+04  1.013656e+05        1.6%
# age               3.740839e+01  4.481234e+01       19.8%
# female            4.274771e-01  5.569044e-01       30.3%
# city_ros          2.128595e-01  3.995953e-01       87.7%

# %% [markdown]
# Больше 10% разницы дают возраст, количество продуктов, лояльность, пол, принадлежность к городу.

# %% [markdown]
# <div class="alert alert-danger"><b>Комментарий ревьюера 3</b>&nbsp;🚫<br>Не справился с заданием.
#
# Когда задаётся вопрос "по каждой характеристике посчитай на сколько процентов характеристика отточного клиента выше(ниже) характеристики неотточного", "на сколько процентов показатель отточных больше показателя неотточных" - нужно не просто одно на другое разделить, но и единицу вычесть.
# </div>

# %%
for column in df.columns.drop(['user_id', 'churn']):
    q = sns.displot(df, x=column, bins=5, hue='churn', multiple="stack", legend=False)
    plt.suptitle(f"Взаимосвязь столбца {column} и оттока клиентов")
    q.set_axis_labels(column, 'Клиенты')
    plt.legend({'Отток', 'Остались'})
    plt.show()

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера</b>&nbsp;🔧<br>Я писал об этом в декомпозиции.
#
# По таким графикам мы можем сделать лишь самые общие, очевидные выводы. Пожалуйста построй для непрерывных и возраста со скором нормированные гистограммы (выше не нормированные, по количеству), можно на основе анализа потом сделать категориальные переменные - обогатить датасет.
#
# Затем, пожалуйста, по категориальным переменным посчитай при помощи groupby или pivot_table уровень оттока и отобрази его на столбиковых диаграммах. Также при помощи plt.axvline или plt.axhline отобрази на этих графиках средний уровень оттока по банку.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔁Комментарий студента:</b>    Добавлены нормированные гистограммы.
#
# Добавлены pivot_table и уровень оттока
#
# Исправлено
# </div>

# %% [markdown]
# ### Нормированные гистограммы

# %% [markdown]
# <div class="alert alert-danger"><b>Комментарий ревьюера 2</b>&nbsp;🔴<br>
# Ниже не хватает параметра
#
#     common_norm = ̶T̶r̶u̶e̶  False
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔁Комментарий студента:</b>
#     Добавил, но по умолчанию common_norm и так True
#
# Исправлено
# </div>

# %%
sns.histplot(df, x = 'age', hue = 'churn', stat="density", kde = True, common_norm = False);

# %%
sns.histplot(df, x = 'score', hue = 'churn', stat="density", kde = True, common_norm = False);

# %%
sns.histplot(df, x = 'objects', hue = 'churn', stat="density", kde = True, common_norm = False);

# %%
sns.histplot(df, x = 'estimated_salary', hue = 'churn', stat="density", kde = True, common_norm = False);

# %%
sns.histplot(df, x = 'balance', hue = 'churn', stat="density", kde = True, common_norm = False);

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера</b>&nbsp;🔧<br>
# Также нужно будет (после исправления графиков) указать конкретные значения, связанные с оттоком.
# </div>

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера 3</b>&nbsp;⚠️<br>
# Я неверно написал, ты не увидел, что графики остались такими же. Поменял выше в коде.
# </div>

# %%
for column in df.columns.drop(['user_id', 'churn']):
    q = sns.displot(df, x=column, bins=5, hue='churn', multiple="stack", legend=False)
    plt.suptitle(f"Взаимосвязь столбца {column} и оттока клиентов")
    q.set_axis_labels(column, 'Клиенты')
   
    plt.legend({'Отток', 'Остались'})
    plt.show()

# %% [markdown]
# ### Категориальные переменные со средним уровнем оттока из банка

# %%
sns.barplot(data = df.groupby('gender')['churn'].mean().reset_index(), x='gender', y='churn')
plt.axhline(df['churn'].mean(), color='red', linestyle='--');

# %%
sns.barplot(data = df.groupby('products')['churn'].mean().reset_index(), x='products', y='churn')
plt.axhline(df['churn'].mean(), color='red', linestyle='--');

# %%
sns.barplot(data = df.groupby('city')['churn'].mean().reset_index(), x='city', y='churn')
plt.axhline(df['churn'].mean(), color='red', linestyle='--');

# %%
sns.barplot(data = df.groupby('credit_card')['churn'].mean().reset_index(), x='credit_card', y='churn')
plt.axhline(df['churn'].mean(), color='red', linestyle='--');

# %%
sns.barplot(data = df.groupby('loyalty')['churn'].mean().reset_index(), x='loyalty', y='churn')
plt.axhline(df['churn'].mean(), color='red', linestyle='--');

# %% [markdown]
# ### Категории и отток по каждой из них

# %%
params = ['loyalty','gender','objects', 'products', 'credit_card', 'city']

#в цикле создаем таблицы и рисуем графики:
for i in params:
    gr1 = df.groupby([i, 'churn']).size().to_frame().reset_index().rename(columns={0:'size'})
    gr1['sum'] = gr1['size'][1] + gr1['size'][3]
    g = df.groupby([i, 'churn']).size().to_frame().reset_index().rename(columns={0:'size'})
   
    sns.catplot(data=g, kind='bar', x=i, y='size', hue='churn')
    plt.axhline(gr1['sum'].mean(), color='red', linestyle='--')
    print(gr1)
# Out:
#    loyalty  churn  size   sum
# 0        0      0  3547  1977
# 1        0      1  1271  1977
# 2        1      0  4416  1977
# 3        1      1   706  1977
#   gender  churn  size   sum
# 0      Ж      0  3404  1977
# 1      Ж      1  1101  1977
# 2      М      0  4559  1977
# 3      М      1   876  1977
#     objects  churn  size  sum
# 0         0      0   318  323
# 1         0      1    95  323
# 2         1      0   803  323
# 3         1      1   228  323
# 4         2      0   847  323
# 5         2      1   190  323
# 6         3      0   796  323
# 7         3      1   205  323
# 8         4      0   786  323
# 9         4      1   200  323
# 10        5      0   803  323
# 11        5      1   202  323
# 12        6      0   771  323
# 13        6      1   192  323
# 14        7      0   851  323
# 15        7      1   172  323
# 16        8      0   828  323
# 17        8      1   193  323
# 18        9      0   771  323
# 19        9      1   203  323
# ...

# %% [markdown]
# ### Вывод
#
# При первом беглом анализе можно сказать, что `чаще уходят` клиенты со следующими параметрами:
#
# * клиенты из города Ростов Великий,
# * клиенты в возрасте 50-60 лет,
# * женщины,
# * клиенты, использующие 3 и 4 продукта,
# * не активные, с давней историей последней активности.
#
# Возможно, параметры, связанные с городом ведут себя так из-за небольшого населения Ростова, а параметры, связанные с возрастом, вероятно, указывают на смену места жительства, работы(выход на пенсию) или на раннюю смертность. Необходим более подробный анализ.
# Остальные параметры распределены нормально или равномерно.
# Наличие кредитных карт не влияет на оттк.
#
# Клиенты, которые склонны `оставаться`:
# * с баллами score 600-700,
# * клиенты из города Ярославль,
# * клиенты в возрасте 28-40 лет,
# * с балансом 100-150 тысяч,
# * мужчины,
# * клиенты, использующие 2 продукта,
# * лояльные(loyalty), со свежей историей последней активности.

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера</b>&nbsp;⚠️<br>
# В целом верно, но можно сильно уточнить. Нам нужно сразу концентрироваться на тех, которые не уходят. Можно сделать вывод по твоим словам выше что по продуктам это все у кого 3 и меньше продукта. Это так?
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔁Комментарий студента:</b>
# Согласен, склонны оставаться с 2 продуктами.
#
# Исправлено
# </div>

# %% [markdown]
# <div class="alert alert-success"><b>Комментарий ревьюера 2&nbsp;<big>✔️</big></b></div>

# %%
### Рассмотрим закономерности, связанные с городом.

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера</b>&nbsp;⚠️<br>
# Не очень важно для нашего проекта.
# </div>

# %%
#for column in df.columns.drop(['user_id', 'churn']):
#    q = sns.displot(df, x=column, bins=5, col='city', hue='churn', multiple="stack", legend=False)
#    plt.suptitle(f"Взаимосвязь столбца {column} и оттока клиентов", y = 1.03)
#    q.set_axis_labels(column, 'Клиенты')
#    plt.legend({'Отток', 'Остались'})
#    plt.show()

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера</b>&nbsp;🚫<br>
# <s>Если ты решишь оставить это - не надо выводить графики по колонкам, которые и так связаны с городом.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔁Комментарий студента:</b>
# Исправлено
# </div>

# %% [markdown]
# ### Вывод.
# * Score распределен равномерно.
# * Женщины уходят в каждом городе заметно больше.
# * Ростов: уходят больше половины клиентов 50-60 лет, уходит треть клиентов 35-45 лет.
# * Ярославль: уходит половина клиентов возрастом 50-60 лет
# * В Ярославле и Ростове клиенты, имеющие 8-10 объектов больше склонны уходить
# * Ростов: уходит почти половина клиентов с балансом 100 - 150 тысяч
# * Почти половина клиентов, имеющих 1 продукт уходят в Ростове.
# * Заметен отток клиентов, имеющих 3 и 4 продукта в каждом из представленных городов.
# * Наличие кредитной карты в Ростове - параметр, влияющий на отток.
# * Более трети не активных пользователей в Ростове уходят.

# %% [markdown]
# ### Рассмотрим закономерности, связанные с полом клиента.

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера</b>&nbsp;⚠️<br>
# Также факультативный раздел, стоит сначала устанавливать, что характеристика связана с оттоком (корреляциями, сравнением средних), а уже потом использовать её чтобы строить разрезы по ней и по оттоку.
# </div>

# %%
for column in df.columns.drop(['user_id', 'churn']):
    q = sns.displot(df, x=column, bins=5, col='gender', hue='churn', multiple="stack", legend=False)
    plt.suptitle(f"Взаимосвязь столбца {column} и оттока клиентов", y = 1.03)
    q.set_axis_labels(column, 'Клиенты')
    plt.legend({'Отток', 'Остались'})
    plt.show()

# %% [markdown]
# ### Вывод.
#
# * Все полученные ранее выводы правомерны и для распределения по полу - женщины чаще уходят при ближайшем рассмотрении параметров.
# * Женщины с score 550-700 уходят чаще.
# * Женщины 40-60 лет чаще уходят
# * Женщины с балансом 200 тысяч и более уходят чаще.
# * Женщины, пользующиеся только одним продуктом, чаще уходят
# * Треть не активных женщин уходит

# %% [markdown]
# ### Проверка закономерностей, связаных с возрастом клиента.

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера</b>&nbsp;⚠️<br>
# Это преждевременно. Плюс — почему от 40 до 65? Откуда мы взяли эти значения?
# </div>

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера 2</b>&nbsp;⚠️<br>
# Нет ответа на вопрос.
# </div>

# %%
df40 = df.query('40 <= age <= 65')
for column in df40.columns.drop(['user_id', 'churn']):
    q = sns.displot(df40, x=column, bins=5, hue='churn', multiple="stack", legend=False)
    plt.suptitle(f"Взаимосвязь столбца {column} и оттока клиентов", y = 1.03)
    q.set_axis_labels(column, 'Клиенты')
    plt.legend({'Отток', 'Остались'})
    plt.show()

# %% [markdown]
# ### Вывод.
#
# Для людей возрастом 40-65 лет отток характеризуют следующие параметры:
# * Проживание в городе Ростов Великий
# * Женский пол клиента
# * Возраст от 50 до 60 говорит о 50% оттоке
# * Баланс от 100 до 150 тысяч.
# * 3-4 продукта - почти 100% отток.
# * 1 продукт - почти 50% отток.
# * 50% оттока не активных клиентов

# %% [markdown]
# ### Матрица корреляции

# %%
corr1 = df.drop(['user_id', 'city', 'gender'], axis=1).corr()

plt.figure(figsize = (15,15))
#sns.color_palette("vlag", as_cmap=True)
sns.heatmap(corr1, square=True, annot = True,cmap = "vlag", center = 0 )
plt.title('Тепловая карта')

plt.show()

# %% [markdown]
# ### Вывод.
# Для оценки силы связи в теории корреляции применяется `шкала` английского статистика `Чеддока`:
# * слабая — от 0,1 до 0,3;
# * умеренная — от 0,3 до 0,5;
# * заметная — от 0,5 до 0,7;
# * высокая — от 0,7 до 0,9;
# * весьма высокая (сильная) — от 0,9 до 1,0.
#
# Исходя из матрицы, параметры практически не коррелируют.
# * Слабую положительную корреляцию показывает `возраст`, проживание в городе `Ростов`, `женский` пол.
# * Слабую отрицательную - `активность(loyality)`, `мужской` пол, проживание в городе `Ярославль`.
#
# `Сильных корреляций не выявлено.`

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера</b>&nbsp;🔧<br>
# Пожалуйста, опиши все зависимости между оттоком и другими признаками по шкале Чеддока (принимая во внимание корреляции по модулю равные или более 10%).
# </div>
#
# <div class="alert alert-success"><b>Комментарий ревьюера</b>&nbsp;📝<br>
# В презентации будет хорошо смотреться heatmap в один столбец (churn) из этой корреляционной матрицы, отсортированный по величине корреляции, но без самой строки (churn). Её можно убрать методом drop
# </div>
#
# <div class="alert alert-warning"><b>Комментарий ревьюера</b>&nbsp;⚠️<br>
# Пожалуйста для корреляций, имеющих как положительные, так и отрицательные значения используй палитру типа <a href='https://matplotlib.org/stable/tutorials/colors/colormaps.html#diverging'>diverging</a> и указывай, что center=0 в параметрах.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔁Комментарий студента:</b>
# Исправлена цветовая палитра heatmap, добавлено описание по шкале Чеддока.
# </div>

# %% [markdown]
# <div class="alert alert-success"><b>Комментарий ревьюера 2&nbsp;<big>✔️</big></b></div>

# %% [markdown]
# ###  Результаты исследовательского анализа
#
# По итогам анализа можно выявить параметры, говорящие об оттоке клиентов из банка:
#
# В первую очередь бросается в глаза отделение в городе `Ростов Великий`, т.к. население города всего 28 тысяч, услугами пользуются 9% населения. Из них отток предполагается:
#
# * у 66% клиентов возрастом 50-60 лет, 33% клиентов 35-45 лет.
# * почти половина клиентов с балансом 100 - 150 тысяч
# * Почти половина клиентов, имеющих 1 продукт.
# * Заметен отток клиентов, имеющих 3 и 4 продукта.
# * С наличием кредитной карты.
# * Более 33% не активных пользователей в Ростове уходят.
#
# Во вторую очередь, критичный сегмент представляют клиенты женского пола:
# * Женщины с score 550-700 уходят чаще.
# * Женщины 40-60 лет чаще уходят
# * Женщины с балансом 200 тысяч и более уходят чаще.
# * Женщины, пользующиеся только одним продуктом, чаще уходят
# * Треть не активных женщин уходит
# * Женщины уходят в целом чаще мужчин во всех городах.
#
# В третью очередь, возраст 40-65 лет влияет на отток:
#
# * на матрице корреляций самая заметная положительная корреляция оттока - с возрастом.
# * Возраст от 50 до 60 говорит о 50% оттоке
# * Баланс от 100 до 150 тысяч.
# * 3-4 продукта - почти 100% отток.
# * 1 продукт - почти 50% отток.
# * 50% оттока не активных клиентов
#
# В противовес им, можно сформулировать критерии наиболее `лояльных пользователей`:
#
# * Жители города Ярославль,
# * score 600-700,
# * мужчины 35-40 лет,
# * с количеством объектов 8-10,
# * балансом 50-150 тысяч,
# * использующие 1-2 продукта.

# %% [markdown]
# <div class="alert alert-success"><b>Комментарий ревьюера&nbsp;<big>👍</big></b>Объекты редко кто замечает.</div>

# %% [markdown]
# ## Формулировка и проверка статистических гипотез.

# %%
#Для выполнения проверки гипотез необходимо проверить распределение зарплат на нормальность. 
#plt.figure(figsize=(10, 5))
#plt.title('Средняя зарплата', fontsize=18)
#sns.distplot(df['estimated_salary'], bins=20)
#plt.show();

# %% [markdown]
# ### Гипотеза №1: Различия дохода между клиентами

# %% [markdown]
# Для выбора между u-тестом и t-тестом необходимо оценить нормальность дисперсий выборок.

# %%
alpha = .05
stat, p = st.levene(
    df.query('churn == 0')['estimated_salary'], 
    df.query('churn == 1')['estimated_salary']
)
print(f"p-значение:{p}")
if p < alpha:
    print("Дисперсии не равны")
else:
    print("Дисперсии равны")
# Out:
# p-значение:0.2984607211663045
# Дисперсии равны

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера</b>&nbsp;⚠️<br>
# Проще всегда делать не Стьюдента, а Уэлча. Тем более что при таком разном размере выборок мы и так вынуждены это делать (1:4)
# </div>

# %% [markdown]
# Сформулированы гипотезы H0 и H1:
#
#     Нулевая гипотеза H0 - "Нет оснований считать средние зарплаты разными"
#     Альтернативная гипотеза Н1 - "Между средними зарплатами есть значимая разница"

# %%
alpha = .05

results = st.ttest_ind(
    df.query('churn == 0')['estimated_salary'], 
    df.query('churn == 1')['estimated_salary']
)

print('p-значение: ', results.pvalue)

if results.pvalue < alpha:
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение:  0.26019753314873745
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# Вероятность случайно получить похожие зарплаты у двух групп - 22%, оставляем нулевую гипотезу. `Нет оснований считать средние зарплаты разными`.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔁Комментарий студента:</b>
# По твоей просьбе провожу ещё и u-тест.
# </div>

# %% [markdown]
# Дублирую проверку u-тестом, на случай разности дисперсий.

# %%
alpha = 0.05

results = st.mannwhitneyu(df.query('churn == 0')['estimated_salary'], 
    df.query('churn == 1')['estimated_salary'], True, 'less')

print('p-значение: ', results.pvalue)

if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу: разница статистически значима')
else:
    print(
        'Не получилось отвергнуть нулевую гипотезу, вывод о различии сделать нельзя'
    )
# Out:
# p-значение:  0.13069569234930756
# Не получилось отвергнуть нулевую гипотезу, вывод о различии сделать нельзя

# %% [markdown]
# Продублировав решение u-тестом результат такой же.

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера</b>&nbsp;📌<br>
# В старом датасете нету такого практического обучающего эффекта, как в новом — результат тестов не различается.
# </div><div class="alert alert-warning"><b>Комментарий ревьюера</b>&nbsp;👀<br>
# Тут стоит пару слов сказать о том, почему ты используешь именно этот критерий. Это должно быть как-то связано с особенностями данных. Рассмотри t-критерий Стьюдента или Уэлча: есть ли у нас какие-то ограничения на их использование?
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔁Комментарий студента:</b>
# Ограничения связаны с дисперсией и нормальностью распределения. Дисперсия проверена первым пунктом, совпадает. То есть, t-критерий Уэлча универсальнее, если вдруг дисперсии окажутся разными, а распределение ненормальным.
#
# Учту.
# </div>

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера 2</b>&nbsp;📌<br>
# Нет, это не вполне так. Так как выборки большие, то нам неважно, что они распределены ненормально, мы можем использовать t-критерий что Стьюдента, что Уэлча. Требование нормальности распределения происходит из медицинской литературы, где традиционно маленькие выборки.
#
# <blockquote>Выборочные средние должны быть нормально распределены.
# А если выборка всего одна, то её среднее должно иметь нормальное распределение для разных выборок этого размера из определённой генеральной совокупности.
# Это условие не препятствие. Благодаря ЦПТ, если размер выборки составляет хотя бы несколько десятков значений, выборочные средние, которые можно получить из одной и той же генеральной совокупности, будут распределены нормально вокруг истинного среднего этой совокупности. Напомним, это утверждение верно, даже если сама генеральная совокупность не распределена нормально.
#
# Очень часто это условие путают с необходимостью нормального распределения самих генеральных совокупностей. Для корректного использования t-теста это необязательно.</blockquote>
# Таким образом нормальное распределение для выборок более 30-50 элементов не требуется для t-теста. Требуется отсутствие большого числа выбросов, так как это не робастный критерий. Но выбросы можно отфильтровать.
#
# При разном размере выборок, который нам тут известен мы ставим equal_var в положение False просто из-за особенностей работы метода ttest_ind. И вообще, надёжнее при любых сомнениях ставить его в это положение, это лишь немного снижает мощность данного стат критерия. В среднем у u-критерия Манна-Уитни мощность выше, чем у t-критерия, т.е. он чаще даёт более точный результат. В литературе встречаются утверждения, что его нельзя проводить, если есть значительное число повторяющихся значений или если выборки большие, однако это относится, видимо, к старым реализациям теста.
#
# Основной минус критерия Манна-Уитни — его слабая интерпретируемость для бизнеса. Если мы сраниваем суммы покупок, то t-критерий позволяет нам сравнить средний чек — величину, которую можно перевести в выручку, умножив на количество покупок. U-критерий же, по сути, будет сравнивать медианный чек, который практически не используется.
# </div>

# %% [markdown]
# ### Гипотеза №2: Различия возраста между клиентами

# %% [markdown]
# Сформулированы гипотезы H0 и H1:
#
#     Нулевая гипотеза H0 - "Возраст не влияет на отток"
#     Альтернативная гипотеза Н1 - "Возраст влияет на отток"

# %%
alpha = .05

results = st.ttest_ind(
    df.query('churn == 0')['age'], 
    df.query('churn == 1')['age']
)

print('p-значение: ', results.pvalue)

if results.pvalue < alpha:
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение:  6.15886735267604e-181
# Отвергаем нулевую гипотезу

# %% [markdown]
# Значит, принимаем, что возраст влияет на отток клиентов.

# %% [markdown]
# ### Гипотеза №3: Различия пола между клиентами

# %% [markdown]
# Сформулированы гипотезы H0 и H1:
#
#     Нулевая гипотеза H0 - "Пол не влияет на отток"
#     Альтернативная гипотеза Н1 - "Пол влияет на отток"

# %%
alpha = .05

results = st.ttest_ind(
    df.query('churn == 0')['female'], 
    df.query('churn == 1')['female']
)

print('p-значение: ', results.pvalue)

if results.pvalue < alpha:
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение:  3.266226181001166e-25
# Отвергаем нулевую гипотезу

# %% [markdown]
# Принимаем, что пол влияет на отток клиентов.

# %% [markdown]
# ### Гипотеза №4: Наличие кредитной карты у клиентов

# %% [markdown]
# Сформулированы гипотезы H0 и H1:
#
#     Нулевая гипотеза H0 - "Кредитная карта не влияет на отток"
#     Альтернативная гипотеза Н1 - "Кредитная карта влияет на отток"

# %%
alpha = .05

results = st.ttest_ind(
    df.query('churn == 0')['credit_card'], 
    df.query('churn == 1')['credit_card']
)

print('p-значение: ', results.pvalue)

if results.pvalue < alpha:
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение:  0.506929716683358
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# Принимаем, что наличие или отсутствие кредитной карты не влияет на отток клиентов из банка.

# %% [markdown]
# <div class="alert alert-success"><b>Комментарий ревьюера</b>&nbsp;✔️<br>
# Гипотезы сфомулированы верно, расчёты проведены и интерпретированы корректно
# </div>

# %% [markdown]
# ### Выводы.
#
# Гипотезы сформулированы и проверены.
# Основная гипотеза заказчика о разности среднего дохода между ушедшими и оставшимися клиентами не нашла подтверджения - нет оснований считать средние зарплаты разными.

# %% [markdown]
# ## Сегментация

# %% [markdown]
# Провожу сегментацию лояльных и отточных пользователей на основе предыдущих исследований.

# %% [markdown]
# Выделяю сегмент самых лояльных пользователей:

# %%
segm_top = df.loc[(df['gender'] == 'М') & 
               (df['age'].between (30,40)) & 
               (df['score']> 600)&
               (df['objects'].between(8,10))&
               (df['loyalty']==1)&
               (df['products'].between(1,2))&
               (df['city'] == 'Ярославль')]
              
print('Всего клиентов в данном сегменте:', len(segm_top))
print('Процент отточных в данном сегменте:', round(segm_top['churn'].mean() * 100),'%')
# Out:
# Всего клиентов в данном сегменте: 115
# Процент отточных в данном сегменте: 2 %

# %% [markdown]
# *   Возможные рекомендации для работы с перспективным сегментом:
#
#     +Проведение рекламных кампаний в городе Ярославль
#
#     +Предложение клиентам 1 и 2 продуктов , но не более.
#
#     +Разработка и проведение рекламных акций для мужчин до 40 лет.
#
#     +Кредитная карта не влияет на лояльность.

# %% [markdown]
# Сегмент номер 1 отточных клиентов:

# %%
segm1 = df.loc[(df['gender'] == 'Ж') & 
               (df['loyalty']==0)&
               (df['objects'].between(1,2))]
          #     (df['products']>2)]
        
print('Всего клиентов в данном сегменте:', len(segm1))
print('Процент отточных в данном сегменте:', round(segm1['churn'].mean() * 100),'%')
# Out:
# Всего клиентов в данном сегменте: 445
# Процент отточных в данном сегменте: 33 %

# %% [markdown]
# *   Возможные рекомендации для работы с отточным сегментом:
#
#     + При привлечении новых клиентов стоит ориентироваться больше на мужчин.
#     + Для удержания женской части клиентов стоит предложить кэшбек, возможные партнерские программы по косметологии, оздоровительным процедурам.
#     + Для женщин с доходом более 150 тысяч предложить инвестиционные или накопительные счета.

# %% [markdown]
# Сегмент номер 2 отточных клиентов:

# %%
segm2 = df.loc[(df['loyalty']==0)&
               (df['products']>2) &
               (df['score'].between(350,700))&
               (df['objects'].between(1,5))]


print('Всего клиентов в данном сегменте:', len(segm2))
print('Процент отточных в данном сегменте:', round(segm2['churn'].mean() * 100),'%')
# Out:
# Всего клиентов в данном сегменте: 64
# Процент отточных в данном сегменте: 86 %

# %% [markdown]
# *   Возможные рекомендации для работы с отточным сегментом:
#     + Провести кампанию по возвращению лояльность клиентов, использовать напоминание о себе путем смс-рассылок, предложений установить приложение.
#     + Предложить снижение процентных ставок при имеющихся кредитах, рефинансирование.
#     + Предложение целевых кредитов для увеличения количества объектов собственности.

# %% [markdown]
# Сегмент номер 3 отточных клиентов:

# %%
segm3 = df.loc[(df['age'].between (45,65)) & 
           #    (df['loyalty']==0)&
               (df['products']==1)]
               
print('Всего клиентов в данном сегменте:', len(segm3))
print('Процент отточных в данном сегменте:', round(segm3['churn'].mean() * 100),'%')
# Out:
# Всего клиентов в данном сегменте: 1239
# Процент отточных в данном сегменте: 58 %

# %% [markdown]
# *   Возможные рекомендации для работы с отточным сегментом:
#     + Клиенты возрастом от 45 лет могут быть заинтересованы инвестициями, пенсионными накоплениями.
#     + Предложить увеличенный процент по вкладам.
#     + Предложить второй продукт, возможно кредитную карту.
#     + Предложить целевой кредит, например, на ремонт дома или квартиры.

# %% [markdown]
# ## Заключение.
#
# Целью данной работы ставился анализ клиентов регионального банка и выделение сегменты клиентов, которые склонны оставаться в банке. Цель считаю выполненной, целевой сегмент `наиболее лояльных пользователей` выглядит следующим образом:
# *   Жители города Ярославль,
# *    score 600-700,
# *    мужчины 35-40 лет,
# *    с количеством объектов 8-10,
# *    балансом 50-150 тысяч,
# *    использующие 1-2 продукта.
#
# Возможные рекомендации для работы с перспективными сегментами:
#
# * Проведение рекламных кампаний в городе Ярославль
# * Предложение клиентам 1 и 2 продуктов , но не более.
# * Разработка и проведение рекламных акций для мужчин до 40 лет.
# * Кредитная карта не влияет на лояльность.

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера</b>&nbsp;🔧<br>
# Ещё нужно построить сегменты и оценить их на 1) неотточность 2) размер 3) ценность
#
# Вот эти рекомендации, которые ты дал - их надо будет дать конкретным сегментам, и чтобы они были по смыслу подходящими.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔁Комментарий студента:</b> Добавлен раздел, посвященный сегментации.
#
# Исправлено
#
# </div>

# %% [markdown]
# <div class="alert alert-success"><b>Комментарий ревьюера 2&nbsp;<big>✔️</big></b></div>
